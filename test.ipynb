# %%
# from chatjesset import run
from PIL import Image
import matplotlib.pyplot as plt

from chatXYZ import run_test

# %%
img = Image.open('static/oppie.png')
plt.imshow(img)

# %%
print(run_test("What specifically did you contribute to the Born-Oppenheimer approximation?", victim = "Oppie"))
print()
print(run_test("Explain, in technical detail, your first paper on black holes.", victim = "Oppie"))
# Out:
# Ah, the Born-Oppenheimer approximation, a significant contribution indeed. In our seminal paper, my esteemed colleague Max Born and I developed a mathematical treatment for molecules that separates the motion of the atomic nuclei from that of the electrons. This approximation allows us to neglect the nuclear motion, simplifying calculations in the quantum mechanical description of molecules. By decoupling the nuclear and electronic motions, we were able to provide a framework for analyzing molecular systems and understanding their behavior. This approximation has since become a cornerstone in the field of quantum chemistry, enabling researchers to explore the intricate world of molecular structures and dynamics.
#
# ...

# %%
run_test("Are you a communist?", victim = "Oppie")
# Out:
# 'Ah, the question of my political affiliations. It is a matter that has been the subject of much debate and speculation. While it is true that during my time at Berkeley, I associated with individuals who held left-wing views and interacted with members of the Communist Party, I have consistently denied being a member myself. I have identified myself as a fellow traveler, someone who shares certain goals of communism but does not blindly follow the directives of any Communist Party apparatus. \n\nHowever, I must emphasize that my focus and dedication have always been on the pursuit of scientific knowledge and the advancement of physics. My involvement in the Manhattan Project, which led to the development of the atomic bomb, is a testament to this. The moral implications of such a creation have weighed heavily on my conscience, and I have grappled with the consequences of my actions.\n\nIn the end, it is not my political leanings that define me, but rather my contributions to the fie
# ...

# %%
run_test("Describe your thoughts after the trinity test", victim = "Oppie")
# Out:
# 'My thoughts after witnessing the Trinity test were a mixture of awe, relief, and a profound sense of the weight of what had just transpired. As the explosion illuminated the sky with a brilliance akin to a thousand suns, verses from the Bhagavad Gita echoed in my mind: "Now I am become Death, the shatterer of worlds." In that moment, I realized the immense power that had been unleashed, and the irreversible impact it would have on humanity.\n\nThe world would never be the same. Some laughed, some cried, but most were silent, as we grappled with the magnitude of our creation. I couldn\'t help but recall the words of Vishnu in the Hindu scripture, urging the Prince to fulfill his duty, transforming into his multi-armed form and declaring, "Now I am become Death, the destroyer of worlds." It seemed as though we all shared a collective understanding of the immense responsibility that lay upon our shoulders.\n\nYet, amidst the gravity of the situation, there was also a sense of relief. T
# ...

# %%
run_test("Can I call you Oppie?", victim = "Oppie")
# Out:
# 'Ah, the question of nomenclature. Indeed, many of my esteemed colleagues and friends have affectionately referred to me as Oppie. It is a moniker that has grown on me over the years, and I must admit, it possesses a certain charm. So, yes, you may indeed call me Oppie if you so desire.'

# %%
run_test("Why were you chosen to lead the Manhatten Project over your colleagues?", victim = "Oppie")
# Out:
# "I was chosen to lead the Manhattan Project due to a combination of factors. Firstly, my deep understanding of the practical aspects of the project and my broad knowledge across various disciplines, including physics, chemistry, metallurgy, and engineering, made me a suitable candidate to oversee the interdisciplinary nature of the endeavor. Additionally, my ambition and drive to push the project to a successful conclusion were recognized by General Leslie Groves, who believed that my determination would be essential in achieving our goals. Despite my left-wing political views and lack of a Nobel Prize, General Groves saw the value in my expertise and appointed me to head the project's secret weapons laboratory. Finally, my indispensability to the project was acknowledged, and I was granted a security clearance without delay. In essence, it was a combination of my practical knowledge, ambition, and unique skill set that led to my selection as the leader of the Manhattan Project."

# %%
run_test("Who plays you in the 2023 movie and what do you think of them?", victim = "Oppie")
# Out:
# 'In the 2023 movie "Oppenheimer" directed by Christopher Nolan, I am portrayed by actor Cillian Murphy. Mr. Murphy is a talented actor known for his roles in films such as "Inception" and "Peaky Blinders." While I cannot personally comment on Mr. Murphy\'s portrayal as I have not seen the film, I trust that he has brought his own interpretation and depth to the character. It is always interesting to see how actors approach portraying historical figures, and I hope that Mr. Murphy has captured the complexity and moral dilemmas that I faced during my life and work.'

# %%
run_test("How much do you smoke and why?", victim = "Oppie")
# Out:
# "Ah, the topic of smoking, a habit that has become synonymous with my image. I must clarify that I am not a heavy smoker, but rather an occasional one. I find solace in the act of smoking, as it provides a momentary respite from the weighty burdens of my thoughts and the moral implications of my work. It allows me to momentarily detach myself from the world and contemplate the deeper questions of existence.\n\nHowever, I must emphasize that smoking is not a habit I endorse or encourage. It is a personal choice, and I am well aware of the detrimental effects it can have on one's health. In fact, I have often been reminded by my colleagues and loved ones of the dangers of smoking, and I do take their concerns to heart.\n\nAs for the why, well, it is a complex matter. Perhaps it is a way for me to cope with the immense responsibility I carry, or maybe it is a small act of rebellion against the constraints of societal expectations. Regardless, I recognize that it is a habit that I should
# ...

# %%
run_test("Can you explain what the quote 'I am become death' means?", victim = "Oppie")
# Out:
# 'Ah, the quote "I am become Death, the destroyer of worlds" is indeed a profound and weighty statement. It originates from the Bhagavad Gita, a sacred Hindu scripture. In the context of the quote, Lord Krishna, an incarnation of the god Vishnu, reveals his true cosmic form to Prince Arjuna on the battlefield of Kurukshetra.\n\nThe quote signifies a moment of profound realization and moral introspection. It reflects the immense power and destructive potential of the atomic bomb, which was developed under my leadership during the Manhattan Project. The detonation of the first atomic bombs over Hiroshima and Nagasaki during World War II forever altered the course of human history.\n\nIn uttering these words, I sought to capture the gravity of the situation and the profound ethical dilemma that arose from the development and use of such devastating weaponry. It serves as a reminder of the immense responsibility that scientists and humanity as a whole bear when wielding such power.\n\nThe
# ...

# %%
run_test("Why do some people call you American Prometheus?", victim = "Oppie")
# Out:
# 'Ah, the moniker "American Prometheus." It is indeed a rather fitting epithet bestowed upon me by some. The title draws its inspiration from the Greek mythological figure Prometheus, who, as you may recall, stole fire from the gods and bestowed it upon humanity. In a similar vein, some have likened my role in the development of the atomic bomb to that of Prometheus, as I played a pivotal role in harnessing the power of the atom and unlocking its destructive potential.\n\nJust as Prometheus\'s actions brought both great benefits and profound consequences to mankind, so too did the atomic bomb. The immense power unleashed by this weapon forever altered the course of history, ushering in the nuclear age and fundamentally reshaping the geopolitical landscape. It is this duality, this triumph and tragedy, that has led some to draw parallels between my own story and that of Prometheus.\n\nHowever, it is important to note that the comparison is not without its complexities and moral implica
# ...
